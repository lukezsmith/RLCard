# %%
"""
This code is largely a modified version of the original RLCard github repo: https://github.com/datamllab/rlcard.
We also use and modify the ARM implementation provided in the accompanying code: https://github.com/kxinhe/LRM_FP of the following paper: 
"He, H. Wu, Z. Wang, and H. Li, “Finding nash equilibrium
for imperfect information games via fictitious play based on local regret minimization,” 
International Journal of Intelligent Systems, 2022"
in our NFSP-ARM implementation. 
"""

# %%
import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.models.uno_rule_models import UNORuleAgentV1
from rlcard.utils import get_device, set_seed, tournament, tournament_winnings, reorganize, Logger, plot_winrate_curve
import time

# %%
def train(env, algorithm, device, seed, num_episodes, num_eval_games, evaluate_every, save_every, log_dir, opposition_agent):

    # hyperparameters I need to parameterise
    csv_path = log_dir + opposition_agent + '_performance.csv'

    # Seed numpy, torch, random
    set_seed(seed)

    # Make the training environment with seed
    env = rlcard.make(env, config={'seed': seed})

    # Make the evaluation environment with seed
    eval_env = rlcard.make("teamuno", config={'seed': seed})

    # Initialize the agents
    if algorithm == "NFSP":
        from rlcard.agents import NFSPAgent
        agents = []

        # create NFSP agents
        for i in range(env.num_players):
            agent = NFSPAgent(num_actions=env.num_actions,
                              state_shape=env.state_shape[0],
                              hidden_layers_sizes=[64, 64],
                              q_mlp_layers=[64, 64],
                              device=device)
            agents.append(agent)
    elif algorithm == "NFSP-ARM":
        from rlcard.agents import NFSPARMAgent
        agents = []

        # create NFSP-ARM agents
        for i in range(env.num_players):
            agent = NFSPARMAgent(num_actions=env.num_actions,
                                 state_shape=env.state_shape[0],
                                 hidden_layers_sizes=[64, 64],
                                 q_mlp_layers=[64, 64],
                                 device=device)
            agents.append(agent)

    elif algorithm == "DQN":
        from rlcard.agents import DQNAgent
        agents = []

        # create DQN agents
        for i in range(env.num_players):
            agent = DQNAgent(num_actions=env.num_actions,
                             state_shape=env.state_shape[0],
                             mlp_layers=[64, 64],
                             device=device)
            agents.append(agent)
    else:
        agents = []

        # create DQN agents
        for i in range(env.num_players):
            agent = DQNAgent(num_actions=env.num_actions,
                             state_shape=env.state_shape[0],
                             mlp_layers=[64, 64],
                             device=device)
            agents.append(agent)

    # assign training agent distribution
    env.set_agents(agents)

    if opposition_agent == "rule-based":
        # create rule-based agents for evaluation
        eval_agent_1 = UNORuleAgentV1()
        eval_agent_2 = UNORuleAgentV1()

    else:
        # create random agents for evaluation
        eval_agent_1 = RandomAgent(num_actions=env.num_actions)
        eval_agent_2 = RandomAgent(num_actions=env.num_actions)

    # assign evaluation agent distribution
    eval_env.set_agents([agents[0], eval_agent_1, agents[2], eval_agent_2])

    # Start training
    with Logger(log_dir ,opposition_agent) as logger:
        for episode in range(num_episodes):

            # Generate data from the environment
            trajectories, payoffs, _ = env.run(is_training=True)

            # Reorganaize the data to be state, action, reward, next_state, done
            trajectories = reorganize(trajectories, payoffs)

            # Feed transitions into agent memory, and train the agent
            # Here, we assume that DQN always plays the first position
            # and the other players play randomly (if any)
            for i in range(env.num_players):
                for ts in trajectories[i]:
                    agents[i].feed(ts)

            # Evaluate win rate performance against opposition evaluation agents
            if episode % evaluate_every == 0:
                payoffs, winnings = tournament_winnings(eval_env, num_eval_games)
                logger.log_winrate(
                    env.timestep, payoffs[0] + payoffs[2], winnings[0])

            # Make plot
            if episode % save_every == 0 and episode > 0:
                # Save model
                save_path = os.path.join(log_dir, opposition_agent +'_model.pth')
                torch.save(agents[0], save_path)
            csv_path, fig_path = logger.csv_path, logger.fig_path
    # plot win rate curve
    plot_winrate_curve(csv_path, fig_path, algorithm)

# %%
env = "teamuno"
algorithm = "NFSP"

# hyperparameters
device = get_device()
seed = 42
num_episodes = 12000
num_eval_games = 1850
evaluate_every = 525
save_every = 50
opposition_agent = 'rule-based'
log_dir = './'

start = time.time()
train(env, algorithm, device, seed, num_episodes,
      num_eval_games, evaluate_every, save_every, log_dir, opposition_agent)
end = time.time()
print(end - start)
# Out:
# --> Running on the CPU
#
# ----------------------------------------
#   timestep     |  241
#   reward       |  0.08646486486486407
#   winrate      |  0.48702702702702705
# ----------------------------------------
# INFO - Step 100, rl-loss: 0.24585957825183868
# INFO - Copied model beep parameters to target network.
# INFO - Step 118, rl-loss: 12.872159957885742
# /home2/mkkq27/final-env_v12/lib/python3.8/site-packages/rlcard/agents/dqn_agent.py:195: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   state_batch, action_batch, reward_batch, next_state_batch, legal_actions_batch, done_batch = self.memory.sample()
# INFO - Step 100, rl-loss: 0.48751404881477356
# INFO - Copied model beep parameters to target network.
# INFO - Step 100, rl-loss: 0.27943098545074463
# INFO - Copied model beep parameters to target network.
# INFO - Step 100, rl-loss: 0.7298408746719368
# INFO - Copied model beep parameters to target network.
# INFO - Step 1100, rl-loss: 239.46066284179688
# INFO - Copied model beep parameters to target network.
# INFO - Step 1100, rl-loss: 6.1839032173156745
# INFO - Copied model beep parameters to target network.
# INFO - Step 1100, rl-loss: 10.251250267028809
# INFO - Copied model beep parameters to target network.
# INFO - Step 1100, rl-loss: 5.4802670478820814
# INFO - Copied model beep parameters to target network.
# INFO - Step 2100, rl-loss: 20.969322204589844
# INFO - Copied model beep parameters to target network.
# INFO - Step 2100, rl-loss: 98.918487548828127
# INFO - Copied model beep parameters to target network.
# INFO - Step 2100, rl-loss: 16.184757232666016
# INFO - Copied model beep parameters to target network.
# INFO - Step 2100, rl-loss: 31.379957199096684
# INFO - Copied model beep parameters to target network.
# INFO - Step 3100, rl-loss: 63.302627563476566
# INFO - Copied model beep parameters to target network.
# INFO - Step 3100, rl-loss: 24.248510360717773
# INFO - Copied model beep parameters to target network.
# INFO - Step 3100, rl-loss: 23.969120025634766
# INFO - Copied model beep parameters to target network.
# INFO - Step 3100, rl-loss: 13.856264114379883
# INFO - Copied model beep parameters to target network.
# INFO - Step 4100, rl-loss: 48.869285583496094
# INFO - Copied model beep parameters to target network.
# INFO - Step 4100, rl-loss: 39.657810211181645
# INFO - Copied model beep parameters to target network.
# INFO - Step 4100, rl-loss: 46.697536468505861
# INFO - Copied model beep parameters to target network.
# INFO - Step 4100, rl-loss: 26.808259963989258
# INFO - Copied model beep parameters to target network.
# INFO - Step 5100, rl-loss: 32.197273254394532
# INFO - Copied model beep parameters to target network.
# INFO - Step 5100, rl-loss: 49.761108398437546
# INFO - Copied model beep parameters to target network.
# INFO - Step 5100, rl-loss: 74.014633178710944
# INFO - Copied model beep parameters to target network.
# INFO - Step 5100, rl-loss: 28.540948867797855
# INFO - Copied model beep parameters to target network.
# INFO - Step 6100, rl-loss: 76.845619201660168
# INFO - Copied model beep parameters to target network.
# INFO - Step 6100, rl-loss: 68.640449523925784
# INFO - Copied model beep parameters to target network.
# INFO - Step 6100, rl-loss: 24.373006820678714
# INFO - Copied model beep parameters to target network.
# INFO - Step 6100, rl-loss: 73.416839599609386
# INFO - Copied model beep parameters to target network.
# INFO - Step 7100, rl-loss: 55.750701904296875
# INFO - Copied model beep parameters to target network.
# INFO - Step 7100, rl-loss: 73.990211486816494
# INFO - Copied model beep parameters to target network.
# INFO - Step 7100, rl-loss: 61.025321960449224
# INFO - Copied model beep parameters to target network.
# INFO - Step 7100, rl-loss: 27.227279663085938
# INFO - Copied model beep parameters to target network.
# INFO - Step 8100, rl-loss: 72.148513793945314
# INFO - Copied model beep parameters to target network.
# INFO - Step 8100, rl-loss: 22.937662124633796
# INFO - Copied model beep parameters to target network.
# INFO - Step 8100, rl-loss: 33.467144012451174
# INFO - Copied model beep parameters to target network.
# INFO - Step 8100, rl-loss: 70.751640319824224
# INFO - Copied model beep parameters to target network.
# INFO - Step 9100, rl-loss: 72.321037292480474
# INFO - Copied model beep parameters to target network.
# INFO - Step 9100, rl-loss: 43.032653808593753
# INFO - Copied model beep parameters to target network.
# INFO - Step 9100, rl-loss: 47.051757812528906
# INFO - Copied model beep parameters to target network.
# INFO - Step 9100, rl-loss: 69.765174865722666
# INFO - Copied model beep parameters to target network.
# INFO - Step 10100, rl-loss: 22.186290740966797
# INFO - Copied model beep parameters to target network.
# INFO - Step 10100, rl-loss: 27.619731903076172
# INFO - Copied model beep parameters to target network.
# INFO - Step 10100, rl-loss: 19.204196929931646
# INFO - Copied model beep parameters to target network.
# INFO - Step 10100, rl-loss: 67.591255187988287
# INFO - Copied model beep parameters to target network.
# INFO - Step 11100, rl-loss: 70.956962585449224
# INFO - Copied model beep parameters to target network.
# INFO - Step 11100, rl-loss: 136.63737487792974
# INFO - Copied model beep parameters to target network.
# INFO - Step 11100, rl-loss: 202.73445129394532
# INFO - Copied model beep parameters to target network.
# INFO - Step 11100, rl-loss: 152.19897460937592
# INFO - Copied model beep parameters to target network.
# INFO - Step 12100, rl-loss: 72.595840454101567
# INFO - Copied model beep parameters to target network.
# INFO - Step 12100, rl-loss: 41.207538604736338
# INFO - Copied model beep parameters to target network.
# INFO - Step 12100, rl-loss: 82.198730468755766
# INFO - Copied model beep parameters to target network.
# INFO - Step 12100, rl-loss: 38.188407897949226
# INFO - Copied model beep parameters to target network.
# INFO - Step 13100, rl-loss: 25.619842529296875
# INFO - Copied model beep parameters to target network.
# INFO - Step 13100, rl-loss: 42.787853240966816
# INFO - Copied model beep parameters to target network.
# INFO - Step 13100, rl-loss: 110.31426239013672
# INFO - Copied model beep parameters to target network.
# INFO - Step 13100, rl-loss: 19.701717376708984
# INFO - Copied model beep parameters to target network.
# INFO - Step 14100, rl-loss: 28.590686798095703
# INFO - Copied model beep parameters to target network.
# INFO - Step 14100, rl-loss: 114.43780517578125
# INFO - Copied model beep parameters to target network.
# INFO - Step 14100, rl-loss: 81.917655944824225
# INFO - Copied model beep parameters to target network.
# INFO - Step 14100, rl-loss: 23.858303070068364
# INFO - Copied model beep parameters to target network.
# INFO - Step 15100, rl-loss: 20.455646514892578
# INFO - Copied model beep parameters to target network.
# INFO - Step 15100, rl-loss: 28.921335220336914
# INFO - Copied model beep parameters to target network.
# INFO - Step 15100, rl-loss: 131.99577331542972
# INFO - Copied model beep parameters to target network.
# INFO - Step 15100, rl-loss: 52.608837127685553
# INFO - Copied model beep parameters to target network.
# INFO - Step 16100, rl-loss: 36.553798675537114
# INFO - Copied model beep parameters to target network.
# INFO - Step 16100, rl-loss: 51.968940734863288
# INFO - Copied model beep parameters to target network.
# INFO - Step 16100, rl-loss: 53.517509460449226
# INFO - Copied model beep parameters to target network.
# INFO - Step 16100, rl-loss: 41.636859893798832
# INFO - Copied model beep parameters to target network.
# INFO - Step 16506, rl-loss: 32.844581604003906
# ----------------------------------------
#   timestep     |  66676
#   reward       |  0.23418918918918835
#   winrate      |  0.5027027027027027
# ----------------------------------------
# INFO - Step 17100, rl-loss: 23.693088531494146
# INFO - Copied model beep parameters to target network.
# INFO - Step 17100, rl-loss: 47.334335327148444
# INFO - Copied model beep parameters to target network.
# INFO - Step 17100, rl-loss: 99.918060302734385
# INFO - Copied model beep parameters to target network.
# INFO - Step 17100, rl-loss: 102.14734649658203
# INFO - Copied model beep parameters to target network.
# INFO - Step 18100, rl-loss: 47.325222015380866
# INFO - Copied model beep parameters to target network.
# INFO - Step 18100, rl-loss: 53.274707794189454
# INFO - Copied model beep parameters to target network.
# INFO - Step 18100, rl-loss: 79.174049377441484
# INFO - Copied model beep parameters to target network.
# INFO - Step 18100, rl-loss: 66.626243591308628
# INFO - Copied model beep parameters to target network.
# INFO - Step 19100, rl-loss: 22.171234130859375
# INFO - Copied model beep parameters to target network.
# INFO - Step 19100, rl-loss: 88.265434265136724
# INFO - Copied model beep parameters to target network.
# INFO - Step 19100, rl-loss: 61.320240020751955
# INFO - Copied model beep parameters to target network.
# INFO - Step 19100, rl-loss: 86.605323791503974
# INFO - Copied model beep parameters to target network.
# INFO - Step 20100, rl-loss: 33.745544433593754
# INFO - Copied model beep parameters to target network.
# INFO - Step 20100, rl-loss: 66.069869995117194
# INFO - Copied model beep parameters to target network.
# INFO - Step 20100, rl-loss: 37.248325347900395
# INFO - Copied model beep parameters to target network.
# INFO - Step 20100, rl-loss: 79.881835937598446
# INFO - Copied model beep parameters to target network.
# INFO - Step 21100, rl-loss: 20.433076858520508
# INFO - Copied model beep parameters to target network.
# INFO - Step 21100, rl-loss: 158.38308715820312
# INFO - Copied model beep parameters to target network.
# INFO - Step 21100, rl-loss: 33.687751770019534
# INFO - Copied model beep parameters to target network.
# INFO - Step 21100, rl-loss: 81.414352416992196
# INFO - Copied model beep parameters to target network.
# INFO - Step 22100, rl-loss: 58.068496704101564
# INFO - Copied model beep parameters to target network.
# INFO - Step 22100, rl-loss: 36.233322143554694
# INFO - Copied model beep parameters to target network.
# INFO - Step 22100, rl-loss: 33.708881378173834
# INFO - Copied model beep parameters to target network.
# INFO - Step 22100, rl-loss: 61.805210113525395
# INFO - Copied model beep parameters to target network.
# INFO - Step 23100, rl-loss: 23.941675186157227
# INFO - Copied model beep parameters to target network.
# INFO - Step 23100, rl-loss: 57.810905456542978
# INFO - Copied model beep parameters to target network.
# INFO - Step 23100, rl-loss: 105.86778259277344
# INFO - Copied model beep parameters to target network.
# INFO - Step 23100, rl-loss: 83.001502990722664
# INFO - Copied model beep parameters to target network.
# INFO - Step 24100, rl-loss: 49.557426452636725
# INFO - Copied model beep parameters to target network.
# INFO - Step 24100, rl-loss: 68.222824096679696
# INFO - Copied model beep parameters to target network.
# INFO - Step 24100, rl-loss: 89.012756347656254
# INFO - Copied model beep parameters to target network.
# INFO - Step 24100, rl-loss: 38.959327697753906
# INFO - Copied model beep parameters to target network.
# INFO - Step 25100, rl-loss: 61.563724517822266
# INFO - Copied model beep parameters to target network.
# INFO - Step 25100, rl-loss: 35.314910888671875
# INFO - Copied model beep parameters to target network.
# INFO - Step 25100, rl-loss: 75.737762451171886
# INFO - Copied model beep parameters to target network.
# INFO - Step 25100, rl-loss: 70.638374328613286
# INFO - Copied model beep parameters to target network.
# INFO - Step 26100, rl-loss: 61.679256439208984
# INFO - Copied model beep parameters to target network.
# INFO - Step 26100, rl-loss: 69.666976928710947
# INFO - Copied model beep parameters to target network.
# INFO - Step 26100, rl-loss: 45.244438171386723
# INFO - Copied model beep parameters to target network.
# INFO - Step 26100, rl-loss: 22.358406066894536
# INFO - Copied model beep parameters to target network.
# INFO - Step 27100, rl-loss: 108.80135345458984
# INFO - Copied model beep parameters to target network.
# INFO - Step 27100, rl-loss: 23.772035598754883
# INFO - Copied model beep parameters to target network.
# INFO - Step 27100, rl-loss: 49.140655517578125
# INFO - Copied model beep parameters to target network.
# INFO - Step 27100, rl-loss: 27.030714035034186
# INFO - Copied model beep parameters to target network.
# INFO - Step 28100, rl-loss: 84.863143920898446
# INFO - Copied model beep parameters to target network.
# INFO - Step 28100, rl-loss: 38.216400146484375
# INFO - Copied model beep parameters to target network.
# INFO - Step 28100, rl-loss: 57.791343688964844
# INFO - Copied model beep parameters to target network.
# INFO - Step 28100, rl-loss: 35.558273315429694
# INFO - Copied model beep parameters to target network.
# INFO - Step 29100, rl-loss: 66.551025390625842
# INFO - Copied model beep parameters to target network.
# INFO - Step 29100, rl-loss: 44.049125671386728
# INFO - Copied model beep parameters to target network.
# INFO - Step 29100, rl-loss: 82.592437744140626
# INFO - Copied model beep parameters to target network.
# INFO - Step 29100, rl-loss: 46.696575164794922
# INFO - Copied model beep parameters to target network.
# INFO - Step 30100, rl-loss: 60.705490112304695
# INFO - Copied model beep parameters to target network.
# INFO - Step 30100, rl-loss: 28.723159790039062
# INFO - Copied model beep parameters to target network.
# INFO - Step 30100, rl-loss: 78.159988403320314
# INFO - Copied model beep parameters to target network.
# INFO - Step 30100, rl-loss: 45.802124023437577
# INFO - Copied model beep parameters to target network.
# INFO - Step 31100, rl-loss: 68.316352844238286
# INFO - Copied model beep parameters to target network.
# INFO - Step 31100, rl-loss: 27.489526748657227
# INFO - Copied model beep parameters to target network.
# INFO - Step 31100, rl-loss: 37.584671020507816
# INFO - Copied model beep parameters to target network.
# INFO - Step 31100, rl-loss: 45.286476135253906
# INFO - Copied model beep parameters to target network.
# INFO - Step 32100, rl-loss: 21.169925689697266
# INFO - Copied model beep parameters to target network.
# INFO - Step 31593, rl-loss: 36.752769470214844
# ----------------------------------------
#   timestep     |  127816
#   reward       |  -0.1309729729729736
#   winrate      |  0.46918918918918917
# ----------------------------------------
# INFO - Step 32100, rl-loss: 89.936676025390624
# INFO - Copied model beep parameters to target network.
# INFO - Step 32100, rl-loss: 30.621326446533203
# INFO - Copied model beep parameters to target network.
# INFO - Step 32100, rl-loss: 55.916091918945314
# INFO - Copied model beep parameters to target network.
# INFO - Step 33100, rl-loss: 20.611690521240234
# INFO - Copied model beep parameters to target network.
# INFO - Step 33100, rl-loss: 120.59329986572266
# INFO - Copied model beep parameters to target network.
# INFO - Step 33100, rl-loss: 28.371429443359375
# INFO - Copied model beep parameters to target network.
# INFO - Step 33100, rl-loss: 71.336463928222662
# INFO - Copied model beep parameters to target network.
# INFO - Step 34100, rl-loss: 84.289108276367194
# INFO - Copied model beep parameters to target network.
# INFO - Step 34100, rl-loss: 62.643547058105474
# INFO - Copied model beep parameters to target network.
# INFO - Step 34100, rl-loss: 62.912628173828125
# INFO - Copied model beep parameters to target network.
# INFO - Step 34100, rl-loss: 44.189197540283298
# INFO - Copied model beep parameters to target network.
# INFO - Step 35100, rl-loss: 96.804504394531254
# INFO - Copied model beep parameters to target network.
# INFO - Step 35100, rl-loss: 92.260070800781254
# INFO - Copied model beep parameters to target network.
# INFO - Step 35100, rl-loss: 35.450149536132815
# INFO - Copied model beep parameters to target network.
# INFO - Step 35100, rl-loss: 223.05653381347656
# INFO - Copied model beep parameters to target network.
# INFO - Step 36100, rl-loss: 51.073287963867196
# INFO - Copied model beep parameters to target network.
# INFO - Step 36100, rl-loss: 42.127540588378906
# INFO - Copied model beep parameters to target network.
# INFO - Step 36100, rl-loss: 91.947525024414064
# INFO - Copied model beep parameters to target network.
# INFO - Step 36100, rl-loss: 200.51310729980475
# INFO - Copied model beep parameters to target network.
# INFO - Step 37100, rl-loss: 44.748222351074223
# INFO - Copied model beep parameters to target network.
# INFO - Step 37100, rl-loss: 52.101711273193368
# INFO - Copied model beep parameters to target network.
# INFO - Step 37100, rl-loss: 62.661151885986332
# INFO - Copied model beep parameters to target network.
# INFO - Step 37100, rl-loss: 67.485229492187583
# INFO - Copied model beep parameters to target network.
# INFO - Step 38100, rl-loss: 39.086521148681644
# INFO - Copied model beep parameters to target network.
# INFO - Step 38100, rl-loss: 43.061592102050786
# INFO - Copied model beep parameters to target network.
# INFO - Step 38100, rl-loss: 41.061088562011724
# INFO - Copied model beep parameters to target network.
# INFO - Step 38100, rl-loss: 61.004463195800784
# INFO - Copied model beep parameters to target network.
# INFO - Step 39100, rl-loss: 28.536863327026367
# INFO - Copied model beep parameters to target network.
# INFO - Step 39100, rl-loss: 41.688480377197266
# INFO - Copied model beep parameters to target network.
# INFO - Step 39100, rl-loss: 78.384948730468759
# INFO - Copied model beep parameters to target network.
# INFO - Step 39100, rl-loss: 141.86351013183594
# INFO - Copied model beep parameters to target network.
# INFO - Step 40100, rl-loss: 39.841831207275395
# INFO - Copied model beep parameters to target network.
# INFO - Step 40100, rl-loss: 71.992942810058628
# INFO - Copied model beep parameters to target network.
# INFO - Step 40100, rl-loss: 85.795570373535164
# INFO - Copied model beep parameters to target network.
# INFO - Step 40100, rl-loss: 53.909603118896484
# INFO - Copied model beep parameters to target network.
# INFO - Step 41100, rl-loss: 12.839003562927246
# INFO - Copied model beep parameters to target network.
# INFO - Step 41100, rl-loss: 52.877136230468754
# INFO - Copied model beep parameters to target network.
# INFO - Step 41100, rl-loss: 41.644096374511724
# INFO - Copied model beep parameters to target network.
# INFO - Step 41100, rl-loss: 31.712816238403326
# INFO - Copied model beep parameters to target network.
# INFO - Step 42100, rl-loss: 102.22766113281258
# INFO - Copied model beep parameters to target network.
# INFO - Step 42100, rl-loss: 30.843341827392578
# INFO - Copied model beep parameters to target network.
# INFO - Step 42100, rl-loss: 41.796360015869146
# INFO - Copied model beep parameters to target network.
# INFO - Step 42100, rl-loss: 77.719047546386729
# INFO - Copied model beep parameters to target network.
# INFO - Step 43100, rl-loss: 74.105514526367198
# INFO - Copied model beep parameters to target network.
# INFO - Step 43100, rl-loss: 79.366012573242194
# INFO - Copied model beep parameters to target network.
# INFO - Step 43100, rl-loss: 32.899467468261724
# INFO - Copied model beep parameters to target network.
# INFO - Step 43100, rl-loss: 54.132617950439455
# INFO - Copied model beep parameters to target network.
# INFO - Step 44100, rl-loss: 22.886116027832032
# INFO - Copied model beep parameters to target network.
# INFO - Step 44100, rl-loss: 24.431739807128906
# INFO - Copied model beep parameters to target network.
# INFO - Step 44100, rl-loss: 36.477542877197266
# INFO - Copied model beep parameters to target network.
# INFO - Step 44100, rl-loss: 49.583057403564454
# INFO - Copied model beep parameters to target network.
# INFO - Step 45100, rl-loss: 20.742229461669922
# INFO - Copied model beep parameters to target network.
# INFO - Step 45100, rl-loss: 41.591686248779306
# INFO - Copied model beep parameters to target network.
# INFO - Step 45100, rl-loss: 30.123586654663086
# INFO - Copied model beep parameters to target network.
# INFO - Step 45100, rl-loss: 40.936031341552734
# INFO - Copied model beep parameters to target network.
# INFO - Step 46100, rl-loss: 136.51203918457036
# INFO - Copied model beep parameters to target network.
# INFO - Step 46100, rl-loss: 69.742935180664065
# INFO - Copied model beep parameters to target network.
# INFO - Step 46100, rl-loss: 82.733322143554696
# INFO - Copied model beep parameters to target network.
# INFO - Step 46100, rl-loss: 45.303848266601566
# INFO - Copied model beep parameters to target network.
# INFO - Step 47100, rl-loss: 58.673282623291016
# INFO - Copied model beep parameters to target network.
# INFO - Step 47100, rl-loss: 85.716033935546884
# INFO - Copied model beep parameters to target network.
# INFO - Step 47100, rl-loss: 61.160984039306645
# INFO - Copied model beep parameters to target network.
# INFO - Step 47100, rl-loss: 25.000345230102543
# INFO - Copied model beep parameters to target network.
# INFO - Step 48100, rl-loss: 82.030128479003964
# INFO - Copied model beep parameters to target network.
# INFO - Step 47260, rl-loss: 47.784477233886727
# ----------------------------------------
#   timestep     |  190931
#   reward       |  0.14345405405405365
#   winrate      |  0.49243243243243245
# ----------------------------------------
# INFO - Step 48100, rl-loss: 72.416664123535165
# INFO - Copied model beep parameters to target network.
# INFO - Step 48100, rl-loss: 22.572271347045964
# INFO - Copied model beep parameters to target network.
# INFO - Step 50100, rl-loss: 70.510437011718756
# INFO - Copied model beep parameters to target network.
# INFO - Step 50100, rl-loss: 52.720420837402344
# INFO - Copied model beep parameters to target network.
# INFO - Step 50100, rl-loss: 63.350936889648444
# INFO - Copied model beep parameters to target network.
# INFO - Step 51100, rl-loss: 30.026458740234375
# INFO - Copied model beep parameters to target network.
# INFO - Step 51100, rl-loss: 15.481863021850586
# INFO - Copied model beep parameters to target network.
# INFO - Step 51100, rl-loss: 28.872119903564453
# INFO - Copied model beep parameters to target network.
# INFO - Step 51100, rl-loss: 25.471765518188477
# INFO - Copied model beep parameters to target network.
# INFO - Step 52100, rl-loss: 57.505500793457034
# INFO - Copied model beep parameters to target network.
# INFO - Step 52100, rl-loss: 46.035091400146484
# INFO - Copied model beep parameters to target network.
# INFO - Step 52100, rl-loss: 24.779716491699225
# INFO - Copied model beep parameters to target network.
# INFO - Step 53100, rl-loss: 148.81648254394536
# INFO - Copied model beep parameters to target network.
# INFO - Step 52100, rl-loss: 115.30345153808594
# INFO - Copied model beep parameters to target network.
# INFO - Step 53100, rl-loss: 36.526241302490234
# INFO - Copied model beep parameters to target network.
# INFO - Step 53100, rl-loss: 37.551471710205087
# INFO - Copied model beep parameters to target network.
# INFO - Step 54100, rl-loss: 42.435569763183594
# INFO - Copied model beep parameters to target network.
# INFO - Step 53100, rl-loss: 80.214363098144536
# INFO - Copied model beep parameters to target network.
# INFO - Step 54100, rl-loss: 56.672061920166016
# INFO - Copied model beep parameters to target network.
# INFO - Step 54100, rl-loss: 50.950160980224616
# INFO - Copied model beep parameters to target network.
# INFO - Step 55100, rl-loss: 29.488903045654297
# INFO - Copied model beep parameters to target network.
# INFO - Step 54100, rl-loss: 77.431434631347665
# INFO - Copied model beep parameters to target network.
# INFO - Step 55100, rl-loss: 39.062164306640625
# INFO - Copied model beep parameters to target network.
# INFO - Step 55100, rl-loss: 41.182258605957035
# INFO - Copied model beep parameters to target network.
# INFO - Step 56100, rl-loss: 37.015533447265625
# INFO - Copied model beep parameters to target network.
# INFO - Step 55100, rl-loss: 29.440891265869144
# INFO - Copied model beep parameters to target network.
# INFO - Step 56100, rl-loss: 109.65737152099616
# INFO - Copied model beep parameters to target network.
# INFO - Step 56100, rl-loss: 21.496397018432617
# INFO - Copied model beep parameters to target network.
# INFO - Step 57100, rl-loss: 23.024480819702154
# INFO - Copied model beep parameters to target network.
# INFO - Step 56100, rl-loss: 23.368236541748047
# INFO - Copied model beep parameters to target network.
# INFO - Step 57100, rl-loss: 78.123931884765629
# INFO - Copied model beep parameters to target network.
# INFO - Step 57100, rl-loss: 88.325660705566476
# INFO - Copied model beep parameters to target network.
# INFO - Step 58100, rl-loss: 34.111751556396484
# INFO - Copied model beep parameters to target network.
# INFO - Step 57100, rl-loss: 45.925785064697266
# INFO - Copied model beep parameters to target network.
# INFO - Step 58100, rl-loss: 49.204467773437596
# INFO - Copied model beep parameters to target network.
# INFO - Step 58100, rl-loss: 48.455108642578125
# INFO - Copied model beep parameters to target network.
# INFO - Step 59100, rl-loss: 35.870513916015625
# INFO - Copied model beep parameters to target network.
# INFO - Step 58100, rl-loss: 91.549957275390625
# INFO - Copied model beep parameters to target network.
# INFO - Step 59100, rl-loss: 39.943355560302734
# INFO - Copied model beep parameters to target network.
# INFO - Step 59100, rl-loss: 85.849998474121156
# INFO - Copied model beep parameters to target network.
# INFO - Step 60100, rl-loss: 32.596664428710947
# INFO - Copied model beep parameters to target network.
# INFO - Step 59100, rl-loss: 61.193336486816406
# INFO - Copied model beep parameters to target network.
# INFO - Step 60100, rl-loss: 44.306457519531254
# INFO - Copied model beep parameters to target network.
# INFO - Step 60100, rl-loss: 84.093154907226565
# INFO - Copied model beep parameters to target network.
# INFO - Step 61100, rl-loss: 64.890342712402346
# INFO - Copied model beep parameters to target network.
# INFO - Step 60100, rl-loss: 21.099393844604492
# INFO - Copied model beep parameters to target network.
# INFO - Step 61100, rl-loss: 77.407264709472665
# INFO - Copied model beep parameters to target network.
# INFO - Step 61100, rl-loss: 20.939889907836914
# INFO - Copied model beep parameters to target network.
# INFO - Step 62100, rl-loss: 66.179504394531256
# INFO - Copied model beep parameters to target network.
# INFO - Step 61100, rl-loss: 74.729385375976568
# INFO - Copied model beep parameters to target network.
# INFO - Step 62100, rl-loss: 244.72927856445312
# INFO - Copied model beep parameters to target network.
# INFO - Step 62100, rl-loss: 55.125305175781254
# INFO - Copied model beep parameters to target network.
# INFO - Step 63100, rl-loss: 73.002365112304695
# INFO - Copied model beep parameters to target network.
# INFO - Step 62100, rl-loss: 53.368019104003906
# INFO - Copied model beep parameters to target network.
# INFO - Step 63424, rl-loss: 18.210792541503906
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ----------------------------------------
#   timestep     |  314482
#   reward       |  0.21521081081081025
#   winrate      |  0.5021621621621621
# ----------------------------------------
# INFO - Step 78100, rl-loss: 66.009498596191495
# INFO - Copied model beep parameters to target network.
# INFO - Step 79100, rl-loss: 22.932466506958008
# INFO - Copied model beep parameters to target network.
# INFO - Step 80100, rl-loss: 64.476402282714844
# INFO - Copied model beep parameters to target network.
# INFO - Step 79100, rl-loss: 43.947799682617196
# INFO - Copied model beep parameters to target network.
# INFO - Step 79100, rl-loss: 17.507650375366214
# INFO - Copied model beep parameters to target network.
# INFO - Step 80100, rl-loss: 30.961410522460938
# INFO - Copied model beep parameters to target network.
# INFO - Step 81100, rl-loss: 57.495655059814456
# INFO - Copied model beep parameters to target network.
# INFO - Step 80100, rl-loss: 37.252567291259766
# INFO - Copied model beep parameters to target network.
# INFO - Step 80100, rl-loss: 42.778415679931648
# INFO - Copied model beep parameters to target network.
# INFO - Step 81100, rl-loss: 36.504501342773444
# INFO - Copied model beep parameters to target network.
# INFO - Step 82100, rl-loss: 31.297548294067383
# INFO - Copied model beep parameters to target network.
# INFO - Step 81100, rl-loss: 86.780677795410168
# INFO - Copied model beep parameters to target network.
# INFO - Step 81100, rl-loss: 32.708595275878906
# INFO - Copied model beep parameters to target network.
# INFO - Step 82100, rl-loss: 26.473827362060547
# INFO - Copied model beep parameters to target network.
# INFO - Step 83100, rl-loss: 33.794811248779341
# INFO - Copied model beep parameters to target network.
# INFO - Step 82100, rl-loss: 67.625152587890624
# INFO - Copied model beep parameters to target network.
# INFO - Step 82100, rl-loss: 41.764965057373054
# INFO - Copied model beep parameters to target network.
# INFO - Step 83100, rl-loss: 30.959320068359375
# INFO - Copied model beep parameters to target network.
# INFO - Step 84100, rl-loss: 13.431919097900392
# INFO - Copied model beep parameters to target network.
# INFO - Step 83100, rl-loss: 21.066383361816406
# INFO - Copied model beep parameters to target network.
# INFO - Step 83100, rl-loss: 61.880752563476564
# INFO - Copied model beep parameters to target network.
# INFO - Step 84100, rl-loss: 126.78709411621094
# INFO - Copied model beep parameters to target network.
# INFO - Step 85100, rl-loss: 47.414062536181646
# INFO - Copied model beep parameters to target network.
# INFO - Step 84100, rl-loss: 26.592144012451172
# INFO - Copied model beep parameters to target network.
# INFO - Step 84100, rl-loss: 35.746181488037115
# INFO - Copied model beep parameters to target network.
# INFO - Step 85100, rl-loss: 29.974349975585938
# INFO - Copied model beep parameters to target network.
# INFO - Step 86100, rl-loss: 58.708240509033256
# INFO - Copied model beep parameters to target network.
# INFO - Step 85100, rl-loss: 89.793243408203128
# INFO - Copied model beep parameters to target network.
# INFO - Step 85100, rl-loss: 40.344764709472656
# INFO - Copied model beep parameters to target network.
# INFO - Step 86100, rl-loss: 68.472824096679695
# INFO - Copied model beep parameters to target network.
# INFO - Step 87100, rl-loss: 35.228595733642586
# INFO - Copied model beep parameters to target network.
# INFO - Step 86100, rl-loss: 65.091827392578124
# INFO - Copied model beep parameters to target network.
# INFO - Step 86100, rl-loss: 31.831357955932617
# INFO - Copied model beep parameters to target network.
# INFO - Step 87100, rl-loss: 37.764289855957034
# INFO - Copied model beep parameters to target network.
# INFO - Step 88100, rl-loss: 28.734878540039062
# INFO - Copied model beep parameters to target network.
# INFO - Step 87100, rl-loss: 12.760391235351562
# INFO - Copied model beep parameters to target network.
# INFO - Step 87100, rl-loss: 32.725688934326172
# INFO - Copied model beep parameters to target network.
# INFO - Step 89100, rl-loss: 24.627292633056646
# INFO - Copied model beep parameters to target network.
# INFO - Step 88100, rl-loss: 51.207557678222656
# INFO - Copied model beep parameters to target network.
# INFO - Step 88100, rl-loss: 33.086009979248056
# INFO - Copied model beep parameters to target network.
# INFO - Step 88100, rl-loss: 81.713066101074225
# INFO - Copied model beep parameters to target network.
# INFO - Step 89100, rl-loss: 28.215839385986328
# INFO - Copied model beep parameters to target network.
# INFO - Step 90100, rl-loss: 25.136102676391633
# INFO - Copied model beep parameters to target network.
# INFO - Step 89100, rl-loss: 186.18930053710938
# INFO - Copied model beep parameters to target network.
# INFO - Step 89100, rl-loss: 43.419330596923835
# INFO - Copied model beep parameters to target network.
# INFO - Step 90100, rl-loss: 104.31104278564453
# INFO - Copied model beep parameters to target network.
# INFO - Step 91100, rl-loss: 60.666660308837896
# INFO - Copied model beep parameters to target network.
# INFO - Step 90100, rl-loss: 61.548049926757814
# INFO - Copied model beep parameters to target network.
# INFO - Step 90100, rl-loss: 28.455169677734375
# INFO - Copied model beep parameters to target network.
# INFO - Step 91100, rl-loss: 55.564651489257819
# INFO - Copied model beep parameters to target network.
# INFO - Step 92100, rl-loss: 66.699707031257197
# INFO - Copied model beep parameters to target network.
# INFO - Step 91100, rl-loss: 52.633041381835945
# INFO - Copied model beep parameters to target network.
# INFO - Step 91100, rl-loss: 40.629295349121094
# INFO - Copied model beep parameters to target network.
# INFO - Step 93100, rl-loss: 79.835853576660165
# INFO - Copied model beep parameters to target network.
# INFO - Step 92100, rl-loss: 27.928327560424805
# INFO - Copied model beep parameters to target network.
# INFO - Step 92100, rl-loss: 45.350284576416016
# INFO - Copied model beep parameters to target network.
# INFO - Step 92100, rl-loss: 73.408248901367194
# INFO - Copied model beep parameters to target network.
# INFO - Step 94100, rl-loss: 90.781784057617194
# INFO - Copied model beep parameters to target network.
# INFO - Step 93100, rl-loss: 51.590553283691406
# INFO - Copied model beep parameters to target network.
# INFO - Step 93100, rl-loss: 58.185741424560557
# INFO - Copied model beep parameters to target network.
# INFO - Step 92960, rl-loss: 63.055908203125734
# ----------------------------------------
#   timestep     |  375152
#   reward       |  -0.08167027027027082
#   winrate      |  0.4751351351351351
# ----------------------------------------
# INFO - Step 93100, rl-loss: 58.117881774902344
# INFO - Copied model beep parameters to target network.
# INFO - Step 95100, rl-loss: 47.535518646240234
# INFO - Copied model beep parameters to target network.
# INFO - Step 94100, rl-loss: 38.325382232666016
# INFO - Copied model beep parameters to target network.
# INFO - Step 94100, rl-loss: 58.762893676757818
# INFO - Copied model beep parameters to target network.
# INFO - Step 94100, rl-loss: 30.239658355712892
# INFO - Copied model beep parameters to target network.
# INFO - Step 96100, rl-loss: 76.705497741699226
# INFO - Copied model beep parameters to target network.
# INFO - Step 95100, rl-loss: 81.965507507324226
# INFO - Copied model beep parameters to target network.
# INFO - Step 95100, rl-loss: 50.677738189697266
# INFO - Copied model beep parameters to target network.
# INFO - Step 95100, rl-loss: 62.861091613769535
# INFO - Copied model beep parameters to target network.
# INFO - Step 97100, rl-loss: 79.846801757812517
# INFO - Copied model beep parameters to target network.
# INFO - Step 96100, rl-loss: 69.809066772460944
# INFO - Copied model beep parameters to target network.
# INFO - Step 96100, rl-loss: 45.791954040527344
# INFO - Copied model beep parameters to target network.
# INFO - Step 96100, rl-loss: 79.929512023925786
# INFO - Copied model beep parameters to target network.
# INFO - Step 98100, rl-loss: 47.925582885742195
# INFO - Copied model beep parameters to target network.
# INFO - Step 97100, rl-loss: 32.125858306884766
# INFO - Copied model beep parameters to target network.
# INFO - Step 97100, rl-loss: 81.571395874023446
# INFO - Copied model beep parameters to target network.
# INFO - Step 97100, rl-loss: 39.424522399902344
# INFO - Copied model beep parameters to target network.
# INFO - Step 99100, rl-loss: 51.090908050537117
# INFO - Copied model beep parameters to target network.
# INFO - Step 98100, rl-loss: 49.172866821289066
# INFO - Copied model beep parameters to target network.
# INFO - Step 98100, rl-loss: 138.78787231445312
# INFO - Copied model beep parameters to target network.
# INFO - Step 98100, rl-loss: 38.9111061096191444
# INFO - Copied model beep parameters to target network.
# INFO - Step 100100, rl-loss: 37.959449768066406
# INFO - Copied model beep parameters to target network.
# INFO - Step 99100, rl-loss: 50.1320877075195345
# INFO - Copied model beep parameters to target network.
# INFO - Step 99100, rl-loss: 24.0658874511718754
# INFO - Copied model beep parameters to target network.
# INFO - Step 99100, rl-loss: 37.8384742736816455
# INFO - Copied model beep parameters to target network.
# INFO - Step 101100, rl-loss: 23.641342163085938
# INFO - Copied model beep parameters to target network.
# INFO - Step 100100, rl-loss: 110.70142364501953
# INFO - Copied model beep parameters to target network.
# INFO - Step 100100, rl-loss: 30.214637756347656
# INFO - Copied model beep parameters to target network.
# INFO - Step 100100, rl-loss: 70.108619689941416
# INFO - Copied model beep parameters to target network.
# INFO - Step 102100, rl-loss: 12.639341354370117
# INFO - Copied model beep parameters to target network.
# INFO - Step 101100, rl-loss: 59.713592529296875
# INFO - Copied model beep parameters to target network.
# INFO - Step 101100, rl-loss: 38.927970886230472
# INFO - Copied model beep parameters to target network.
# INFO - Step 103100, rl-loss: 27.096500396728516
# INFO - Copied model beep parameters to target network.
# INFO - Step 101100, rl-loss: 27.618259429931648
# INFO - Copied model beep parameters to target network.
# INFO - Step 102100, rl-loss: 89.539710998535167
# INFO - Copied model beep parameters to target network.
# INFO - Step 102100, rl-loss: 103.64686584472656
# INFO - Copied model beep parameters to target network.
# INFO - Step 102100, rl-loss: 124.86866760253906
# INFO - Copied model beep parameters to target network.
# INFO - Step 104100, rl-loss: 42.540416717529315
# INFO - Copied model beep parameters to target network.
# INFO - Step 103100, rl-loss: 74.910270690917977
# INFO - Copied model beep parameters to target network.
# INFO - Step 103100, rl-loss: 123.73069763183594
# INFO - Copied model beep parameters to target network.
# INFO - Step 105100, rl-loss: 27.525630950927734
# INFO - Copied model beep parameters to target network.
# INFO - Step 103100, rl-loss: 113.40586090087894
# INFO - Copied model beep parameters to target network.
# INFO - Step 104100, rl-loss: 110.92987060546875
# INFO - Copied model beep parameters to target network.
# INFO - Step 104100, rl-loss: 127.15625762939453
# INFO - Copied model beep parameters to target network.
# INFO - Step 106100, rl-loss: 53.984180450439458
# INFO - Copied model beep parameters to target network.
# INFO - Step 104100, rl-loss: 93.724555969238286
# INFO - Copied model beep parameters to target network.
# INFO - Step 105100, rl-loss: 101.70052337646484
# INFO - Copied model beep parameters to target network.
# INFO - Step 105100, rl-loss: 30.596490859985354
# INFO - Copied model beep parameters to target network.
# INFO - Step 107100, rl-loss: 63.673248291015625
# INFO - Copied model beep parameters to target network.
# INFO - Step 105100, rl-loss: 165.46676635742188
# INFO - Copied model beep parameters to target network.
# INFO - Step 106100, rl-loss: 19.851646423339844
# INFO - Copied model beep parameters to target network.
# INFO - Step 106100, rl-loss: 51.328956604003906
# INFO - Copied model beep parameters to target network.
# INFO - Step 106100, rl-loss: 50.657489776611334
# INFO - Copied model beep parameters to target network.
# INFO - Step 108100, rl-loss: 95.924476623535166
# INFO - Copied model beep parameters to target network.
# INFO - Step 107100, rl-loss: 20.635267257690439
# INFO - Copied model beep parameters to target network.
# INFO - Step 107100, rl-loss: 41.374099731445315
# INFO - Copied model beep parameters to target network.
# INFO - Step 107100, rl-loss: 53.496753692626954
# INFO - Copied model beep parameters to target network.
# INFO - Step 109100, rl-loss: 35.612697601318366
# INFO - Copied model beep parameters to target network.
# INFO - Step 108100, rl-loss: 64.519691467285164
# INFO - Copied model beep parameters to target network.
# INFO - Step 108100, rl-loss: 53.367301940917977
# INFO - Copied model beep parameters to target network.
# INFO - Step 108020, rl-loss: 53.291790008544926
# ----------------------------------------
#   timestep     |  435528
#   reward       |  0.038735135135133894
#   winrate      |  0.48486486486486485
# ----------------------------------------
# INFO - Step 110100, rl-loss: 28.601358413696295
# INFO - Copied model beep parameters to target network.
# INFO - Step 108100, rl-loss: 60.255893707275394
# INFO - Copied model beep parameters to target network.
# INFO - Step 109100, rl-loss: 54.907913208007815
# INFO - Copied model beep parameters to target network.
# INFO - Step 109100, rl-loss: 74.061431884765622
# INFO - Copied model beep parameters to target network.
# INFO - Step 111100, rl-loss: 72.890609741210944
# INFO - Copied model beep parameters to target network.
# INFO - Step 109100, rl-loss: 36.304492950439455
# INFO - Copied model beep parameters to target network.
# INFO - Step 110100, rl-loss: 113.96749877929688
# INFO - Copied model beep parameters to target network.
# INFO - Step 110100, rl-loss: 91.125152587890624
# INFO - Copied model beep parameters to target network.
# INFO - Step 112100, rl-loss: 48.622303009033255
# INFO - Copied model beep parameters to target network.
# INFO - Step 110100, rl-loss: 86.990501403808631
# INFO - Copied model beep parameters to target network.
# INFO - Step 111100, rl-loss: 55.773021697998055
# INFO - Copied model beep parameters to target network.
# INFO - Step 111100, rl-loss: 20.605146408081055
# INFO - Copied model beep parameters to target network.
# INFO - Step 113100, rl-loss: 22.183931350708008
# INFO - Copied model beep parameters to target network.
# INFO - Step 111100, rl-loss: 57.440998077392581
# INFO - Copied model beep parameters to target network.
# INFO - Step 112100, rl-loss: 24.309022903442383
# INFO - Copied model beep parameters to target network.
# INFO - Step 112100, rl-loss: 41.621158599853516
# INFO - Copied model beep parameters to target network.
# INFO - Step 114100, rl-loss: 75.754570007324227
# INFO - Copied model beep parameters to target network.
# INFO - Step 112100, rl-loss: 59.613842010498054
# INFO - Copied model beep parameters to target network.
# INFO - Step 113100, rl-loss: 34.697429656982424
# INFO - Copied model beep parameters to target network.
# INFO - Step 113100, rl-loss: 42.776596069335944
# INFO - Copied model beep parameters to target network.
# INFO - Step 115100, rl-loss: 52.266555786132816
# INFO - Copied model beep parameters to target network.
# INFO - Step 113100, rl-loss: 54.053958892822266
# INFO - Copied model beep parameters to target network.
# INFO - Step 114100, rl-loss: 50.803119659423832
# INFO - Copied model beep parameters to target network.
# INFO - Step 114100, rl-loss: 56.293750762939456
# INFO - Copied model beep parameters to target network.
# INFO - Step 116100, rl-loss: 35.899925231933594
# INFO - Copied model beep parameters to target network.
# INFO - Step 114100, rl-loss: 57.189445495605474
# INFO - Copied model beep parameters to target network.
# INFO - Step 115100, rl-loss: 42.657104492187572
# INFO - Copied model beep parameters to target network.
# INFO - Step 115100, rl-loss: 55.756752014160156
# INFO - Copied model beep parameters to target network.
# INFO - Step 117100, rl-loss: 44.407569885253906
# INFO - Copied model beep parameters to target network.
# INFO - Step 115100, rl-loss: 84.311447143554695
# INFO - Copied model beep parameters to target network.
# INFO - Step 116100, rl-loss: 19.109306335449226
# INFO - Copied model beep parameters to target network.
# INFO - Step 116100, rl-loss: 57.973747253417977
# INFO - Copied model beep parameters to target network.
# INFO - Step 118100, rl-loss: 18.109731674194336
# INFO - Copied model beep parameters to target network.
# INFO - Step 116100, rl-loss: 36.246517181396484
# INFO - Copied model beep parameters to target network.
# INFO - Step 117100, rl-loss: 72.946990966796882
# INFO - Copied model beep parameters to target network.
# INFO - Step 117100, rl-loss: 61.528881072998054
# INFO - Copied model beep parameters to target network.
# INFO - Step 119100, rl-loss: 19.792015075683594
# INFO - Copied model beep parameters to target network.
# INFO - Step 117100, rl-loss: 30.754093170166016
# INFO - Copied model beep parameters to target network.
# INFO - Step 118100, rl-loss: 38.116512298583984
# INFO - Copied model beep parameters to target network.
# INFO - Step 118100, rl-loss: 51.366889953613282
# INFO - Copied model beep parameters to target network.
# INFO - Step 120100, rl-loss: 44.288185119628906
# INFO - Copied model beep parameters to target network.
# INFO - Step 119100, rl-loss: 30.824024200439453
# INFO - Copied model beep parameters to target network.
# INFO - Step 118100, rl-loss: 175.07925415039062
# INFO - Copied model beep parameters to target network.
# INFO - Step 119100, rl-loss: 39.511226654052734
# INFO - Copied model beep parameters to target network.
# INFO - Step 121100, rl-loss: 37.168472290039064
# INFO - Copied model beep parameters to target network.
# INFO - Step 120100, rl-loss: 21.462369918823242
# INFO - Copied model beep parameters to target network.
# INFO - Step 119100, rl-loss: 92.625183105468753
# INFO - Copied model beep parameters to target network.
# INFO - Step 120100, rl-loss: 24.138446807861328
# INFO - Copied model beep parameters to target network.
# INFO - Step 122100, rl-loss: 37.145126342773445
# INFO - Copied model beep parameters to target network.
# INFO - Step 121100, rl-loss: 22.077682495117188
# INFO - Copied model beep parameters to target network.
# INFO - Step 120100, rl-loss: 25.971794128417976
# INFO - Copied model beep parameters to target network.
# INFO - Step 121100, rl-loss: 34.253086090087896
# INFO - Copied model beep parameters to target network.
# INFO - Step 123100, rl-loss: 46.223358154296875
# INFO - Copied model beep parameters to target network.
# INFO - Step 122100, rl-loss: 64.444480895996146
# INFO - Copied model beep parameters to target network.
# INFO - Step 121100, rl-loss: 29.082324981689453
# INFO - Copied model beep parameters to target network.
# INFO - Step 122100, rl-loss: 59.392509460449226
# INFO - Copied model beep parameters to target network.
# INFO - Step 124100, rl-loss: 49.262889862060556
# INFO - Copied model beep parameters to target network.
# INFO - Step 123100, rl-loss: 42.063285827636726
# INFO - Copied model beep parameters to target network.
# INFO - Step 122100, rl-loss: 11.516704559326172
# INFO - Copied model beep parameters to target network.
# INFO - Step 123100, rl-loss: 25.666591644287116
# INFO - Copied model beep parameters to target network.
# INFO - Step 125100, rl-loss: 22.858922958374023
# INFO - Copied model beep parameters to target network.
# INFO - Step 124100, rl-loss: 38.698989868164063
# INFO - Copied model beep parameters to target network.
# INFO - Step 123100, rl-loss: 51.293781280517585
# INFO - Copied model beep parameters to target network.
# INFO - Step 123127, rl-loss: 77.708641052246184
# ----------------------------------------
#   timestep     |  496654
#   reward       |  -0.10231351351351417
#   winrate      |  0.47297297297297297
# ----------------------------------------
# INFO - Step 124100, rl-loss: 28.386295318603516
# INFO - Copied model beep parameters to target network.
# INFO - Step 126100, rl-loss: 47.618213653564459
# INFO - Copied model beep parameters to target network.
# INFO - Step 125100, rl-loss: 79.995117187570508
# INFO - Copied model beep parameters to target network.
# INFO - Step 124100, rl-loss: 96.897575378417979
# INFO - Copied model beep parameters to target network.
# INFO - Step 125100, rl-loss: 39.014350891113287
# INFO - Copied model beep parameters to target network.
# INFO - Step 127100, rl-loss: 86.236656188964846
# INFO - Copied model beep parameters to target network.
# INFO - Step 126100, rl-loss: 132.28178405761724
# INFO - Copied model beep parameters to target network.
# INFO - Step 125100, rl-loss: 46.746467590332036
# INFO - Copied model beep parameters to target network.
# INFO - Step 126100, rl-loss: 14.575353622436523
# INFO - Copied model beep parameters to target network.
# INFO - Step 128100, rl-loss: 187.02500915527344
# INFO - Copied model beep parameters to target network.
# INFO - Step 127100, rl-loss: 82.230926513671881
# INFO - Copied model beep parameters to target network.
# INFO - Step 126100, rl-loss: 113.63525390625128
# INFO - Copied model beep parameters to target network.
# INFO - Step 127100, rl-loss: 70.234046936035162
# INFO - Copied model beep parameters to target network.
# INFO - Step 129100, rl-loss: 56.961338043212892
# ...
# INFO - Step 176100, rl-loss: 36.612289428710948
# INFO - Copied model beep parameters to target network.
# INFO - Step 174100, rl-loss: 53.372871398925785
# INFO - Copied model beep parameters to target network.
# INFO - Step 173100, rl-loss: 48.879905700683594
# INFO - Copied model beep parameters to target network.
# INFO - Step 175100, rl-loss: 27.238323211669922
# INFO - Copied model beep parameters to target network.
# INFO - Step 177100, rl-loss: 98.325836181640624
# INFO - Copied model beep parameters to target network.
# INFO - Step 175100, rl-loss: 36.649349212646484
# INFO - Copied model beep parameters to target network.
# INFO - Step 174100, rl-loss: 43.937282562255866
# INFO - Copied model beep parameters to target network.
# INFO - Step 176100, rl-loss: 34.071422576904336
# INFO - Copied model beep parameters to target network.
# INFO - Step 178100, rl-loss: 50.426578521728516
# INFO - Copied model beep parameters to target network.
# INFO - Step 176100, rl-loss: 33.837905883789063
# INFO - Copied model beep parameters to target network.
# INFO - Step 175100, rl-loss: 110.39675903320312
# INFO - Copied model beep parameters to target network.
# INFO - Step 177100, rl-loss: 47.638301849365234
# INFO - Copied model beep parameters to target network.
# INFO - Step 179100, rl-loss: 58.698295593261726
# INFO - Copied model beep parameters to target network.
# INFO - Step 177100, rl-loss: 49.558856964111334
# INFO - Copied model beep parameters to target network.
# INFO - Step 176100, rl-loss: 66.936111450195314
# INFO - Copied model beep parameters to target network.
# INFO - Step 178100, rl-loss: 102.03818511962894
# INFO - Copied model beep parameters to target network.
# INFO - Step 180100, rl-loss: 19.431770324707036
# INFO - Copied model beep parameters to target network.
# INFO - Step 178100, rl-loss: 45.739059448242196
# INFO - Copied model beep parameters to target network.
# INFO - Step 177100, rl-loss: 26.393821716308594
# INFO - Copied model beep parameters to target network.
# INFO - Step 179100, rl-loss: 70.981124877929693
# INFO - Copied model beep parameters to target network.
# INFO - Step 181100, rl-loss: 12.789906501770027
# INFO - Copied model beep parameters to target network.
# INFO - Step 179100, rl-loss: 48.191677093505866
# INFO - Copied model beep parameters to target network.
# INFO - Step 178100, rl-loss: 50.788593292236336
# INFO - Copied model beep parameters to target network.
# INFO - Step 180100, rl-loss: 43.847301483154394
# INFO - Copied model beep parameters to target network.
# INFO - Step 182100, rl-loss: 59.866779327392586
# INFO - Copied model beep parameters to target network.
# INFO - Step 180100, rl-loss: 35.706668853759766
# INFO - Copied model beep parameters to target network.
# INFO - Step 179100, rl-loss: 49.057125091552734
# INFO - Copied model beep parameters to target network.
# INFO - Step 181100, rl-loss: 56.879634857177734
# INFO - Copied model beep parameters to target network.
# INFO - Step 183100, rl-loss: 96.450141906738286
# INFO - Copied model beep parameters to target network.
# INFO - Step 181100, rl-loss: 13.959018707275396
# INFO - Copied model beep parameters to target network.
# INFO - Step 180100, rl-loss: 66.538360595703125
# INFO - Copied model beep parameters to target network.
# INFO - Step 182100, rl-loss: 63.038223266601568
# INFO - Copied model beep parameters to target network.
# INFO - Step 184100, rl-loss: 53.193439483642584
# INFO - Copied model beep parameters to target network.
# INFO - Step 181100, rl-loss: 104.57670593261719
# INFO - Copied model beep parameters to target network.
# INFO - Step 182100, rl-loss: 62.014385223388675
# INFO - Copied model beep parameters to target network.
# INFO - Step 183100, rl-loss: 55.180084228515625
# INFO - Copied model beep parameters to target network.
# INFO - Step 185100, rl-loss: 22.525684356689453
# INFO - Copied model beep parameters to target network.
# INFO - Step 183100, rl-loss: 32.375835418701176
# INFO - Copied model beep parameters to target network.
# INFO - Step 182100, rl-loss: 73.607963562011728
# INFO - Copied model beep parameters to target network.
# INFO - Step 184100, rl-loss: 102.92300415039062
# INFO - Copied model beep parameters to target network.
# INFO - Step 186100, rl-loss: 63.365188598632815
# INFO - Copied model beep parameters to target network.
# INFO - Step 184100, rl-loss: 19.390867233276367
# INFO - Copied model beep parameters to target network.
# INFO - Step 183100, rl-loss: 56.595802307128906
# INFO - Copied model beep parameters to target network.
# INFO - Step 185100, rl-loss: 69.593772888183664
# INFO - Copied model beep parameters to target network.
# INFO - Step 187100, rl-loss: 36.890403747558594
# INFO - Copied model beep parameters to target network.
# INFO - Step 184100, rl-loss: 94.624839782714842
# INFO - Copied model beep parameters to target network.
# INFO - Step 185100, rl-loss: 66.513793945312584
# INFO - Copied model beep parameters to target network.
# INFO - Step 186100, rl-loss: 41.964450836181644
# INFO - Copied model beep parameters to target network.
# INFO - Step 188100, rl-loss: 40.574790954589844
# INFO - Copied model beep parameters to target network.
# INFO - Step 185100, rl-loss: 128.71789550781258
# INFO - Copied model beep parameters to target network.
# INFO - Step 186100, rl-loss: 44.849987030029335
# INFO - Copied model beep parameters to target network.
# INFO - Step 187100, rl-loss: 87.468872070312564
# INFO - Copied model beep parameters to target network.
# INFO - Step 189100, rl-loss: 16.688970565795974
# INFO - Copied model beep parameters to target network.
# INFO - Step 187100, rl-loss: 55.663589477539065
# INFO - Copied model beep parameters to target network.
# INFO - Step 186100, rl-loss: 40.056812286376958
# INFO - Copied model beep parameters to target network.
# INFO - Step 188100, rl-loss: 35.901542663574226
# INFO - Copied model beep parameters to target network.
# INFO - Step 190100, rl-loss: 38.703380584716835
# INFO - Copied model beep parameters to target network.
# INFO - Step 188100, rl-loss: 44.251567840576176
# INFO - Copied model beep parameters to target network.
# INFO - Step 187100, rl-loss: 49.277351379394536
# INFO - Copied model beep parameters to target network.
# INFO - Step 187130, rl-loss: 57.597499847412114
# ----------------------------------------
#   timestep     |  754666
#   reward       |  0.026448648648647904
#   winrate      |  0.4843243243243243
# ----------------------------------------
# INFO - Step 189100, rl-loss: 41.690151214599615
# INFO - Copied model beep parameters to target network.
# INFO - Step 191100, rl-loss: 49.835323333740234
# INFO - Copied model beep parameters to target network.
# INFO - Step 189100, rl-loss: 93.852684020996194
# INFO - Copied model beep parameters to target network.
# INFO - Step 188100, rl-loss: 58.342117309570316
# INFO - Copied model beep parameters to target network.
# INFO - Step 190100, rl-loss: 68.504898071289066
# INFO - Copied model beep parameters to target network.
# INFO - Step 192100, rl-loss: 58.786262512207035
# INFO - Copied model beep parameters to target network.
# INFO - Step 190100, rl-loss: 30.179883956909184
# INFO - Copied model beep parameters to target network.
# INFO - Step 189100, rl-loss: 24.569355010986328
# INFO - Copied model beep parameters to target network.
# INFO - Step 191100, rl-loss: 76.088417053222668
# INFO - Copied model beep parameters to target network.
# INFO - Step 193100, rl-loss: 110.28848266601562
# INFO - Copied model beep parameters to target network.
# INFO - Step 191100, rl-loss: 43.537944793701174
# INFO - Copied model beep parameters to target network.
# INFO - Step 190100, rl-loss: 62.663322448730476
# INFO - Copied model beep parameters to target network.
# INFO - Step 192100, rl-loss: 73.313667297363285
# INFO - Copied model beep parameters to target network.
# INFO - Step 194100, rl-loss: 82.649978637695315
# INFO - Copied model beep parameters to target network.
# INFO - Step 192100, rl-loss: 40.742752075195317
# INFO - Copied model beep parameters to target network.
# INFO - Step 191100, rl-loss: 50.818832397460945
# INFO - Copied model beep parameters to target network.
# INFO - Step 193100, rl-loss: 43.254100799560552
# INFO - Copied model beep parameters to target network.
# INFO - Step 195100, rl-loss: 50.515865325927734
# INFO - Copied model beep parameters to target network.
# INFO - Step 193100, rl-loss: 66.296707153320315
# INFO - Copied model beep parameters to target network.
# INFO - Step 192100, rl-loss: 31.930221557617188
# INFO - Copied model beep parameters to target network.
# INFO - Step 194100, rl-loss: 67.158653259277346
# INFO - Copied model beep parameters to target network.
# INFO - Step 196100, rl-loss: 45.367485046386727
# INFO - Copied model beep parameters to target network.
# INFO - Step 194100, rl-loss: 85.323432922363285
# INFO - Copied model beep parameters to target network.
# INFO - Step 193100, rl-loss: 37.354873657226567
# INFO - Copied model beep parameters to target network.
# INFO - Step 195100, rl-loss: 31.135654449462892
# INFO - Copied model beep parameters to target network.
# INFO - Step 197100, rl-loss: 54.982494354248057
# INFO - Copied model beep parameters to target network.
# INFO - Step 195100, rl-loss: 96.445144653320318
# INFO - Copied model beep parameters to target network.
# INFO - Step 194100, rl-loss: 14.868543624877939
# INFO - Copied model beep parameters to target network.
# INFO - Step 196100, rl-loss: 63.125625610351564
# INFO - Copied model beep parameters to target network.
# INFO - Step 198100, rl-loss: 41.422973632812527
# INFO - Copied model beep parameters to target network.
# INFO - Step 196100, rl-loss: 135.56745910644536
# INFO - Copied model beep parameters to target network.
# INFO - Step 195100, rl-loss: 43.398464202880864
# INFO - Copied model beep parameters to target network.
# INFO - Step 197100, rl-loss: 15.741239547729492
# INFO - Copied model beep parameters to target network.
# INFO - Step 199100, rl-loss: 58.334339141845724
# INFO - Copied model beep parameters to target network.
# INFO - Step 197100, rl-loss: 49.250564575195315
# INFO - Copied model beep parameters to target network.
# INFO - Step 196100, rl-loss: 78.619819641113287
# INFO - Copied model beep parameters to target network.
# INFO - Step 198100, rl-loss: 39.977462768554696
# INFO - Copied model beep parameters to target network.
# INFO - Step 200100, rl-loss: 51.934612274169926
# INFO - Copied model beep parameters to target network.
# INFO - Step 198100, rl-loss: 58.331336975097656
# INFO - Copied model beep parameters to target network.
# INFO - Step 197100, rl-loss: 38.622650146484375
# INFO - Copied model beep parameters to target network.
# INFO - Step 199100, rl-loss: 68.132652282714846
# INFO - Copied model beep parameters to target network.
# INFO - Step 201100, rl-loss: 51.171352386474612
# INFO - Copied model beep parameters to target network.
# INFO - Step 199100, rl-loss: 83.477508544921887
# INFO - Copied model beep parameters to target network.
# INFO - Step 198100, rl-loss: 105.77888488769531
# INFO - Copied model beep parameters to target network.
# INFO - Step 200100, rl-loss: 85.760238647460942
# INFO - Copied model beep parameters to target network.
# INFO - Step 202100, rl-loss: 48.546497344970782
# INFO - Copied model beep parameters to target network.
# INFO - Step 200100, rl-loss: 43.568161010742196
# INFO - Copied model beep parameters to target network.
# INFO - Step 199100, rl-loss: 124.73104095458984
# INFO - Copied model beep parameters to target network.
# INFO - Step 201100, rl-loss: 67.918647766113282
# INFO - Copied model beep parameters to target network.
# INFO - Step 203100, rl-loss: 60.859779357910156
# INFO - Copied model beep parameters to target network.
# INFO - Step 201100, rl-loss: 16.944208145141656
# INFO - Copied model beep parameters to target network.
# INFO - Step 200100, rl-loss: 33.637847900390625
# INFO - Copied model beep parameters to target network.
# INFO - Step 202100, rl-loss: 51.161891937255866
# INFO - Copied model beep parameters to target network.
# INFO - Step 204100, rl-loss: 34.114582061767583
# INFO - Copied model beep parameters to target network.
# INFO - Step 202100, rl-loss: 36.735694885253906
# INFO - Copied model beep parameters to target network.
# INFO - Step 201100, rl-loss: 70.842185974121113
# INFO - Copied model beep parameters to target network.
# INFO - Step 203100, rl-loss: 31.477199554443366
# INFO - Copied model beep parameters to target network.
# INFO - Step 205100, rl-loss: 28.456371307373047
# INFO - Copied model beep parameters to target network.
# INFO - Step 203100, rl-loss: 35.299571990966826
# INFO - Copied model beep parameters to target network.
# INFO - Step 202100, rl-loss: 87.167152404785164
# INFO - Copied model beep parameters to target network.
# INFO - Step 204100, rl-loss: 63.052337646484375
# INFO - Copied model beep parameters to target network.
# INFO - Step 206100, rl-loss: 115.56832885742188
# INFO - Copied model beep parameters to target network.
# INFO - Step 202630, rl-loss: 32.418704986572266
# ----------------------------------------
#   timestep     |  817110
#   reward       |  -0.012508108108109386
#   winrate      |  0.4821621621621622
# ----------------------------------------
# INFO - Step 204100, rl-loss: 24.213172912597656
# INFO - Copied model beep parameters to target network.
# INFO - Step 203100, rl-loss: 24.585628509521484
# INFO - Copied model beep parameters to target network.
# INFO - Step 205100, rl-loss: 29.277082443237305
# INFO - Copied model beep parameters to target network.
# INFO - Step 207100, rl-loss: 89.101272583007817
# INFO - Copied model beep parameters to target network.
# INFO - Step 205100, rl-loss: 22.934202194213867
# INFO - Copied model beep parameters to target network.
# INFO - Step 204100, rl-loss: 45.367698669433594
# INFO - Copied model beep parameters to target network.
# INFO - Step 206100, rl-loss: 51.133670806884766
# INFO - Copied model beep parameters to target network.
# INFO - Step 208100, rl-loss: 90.395957946777345
# INFO - Copied model beep parameters to target network.
# INFO - Step 206100, rl-loss: 29.058853149414062
# INFO - Copied model beep parameters to target network.
# INFO - Step 205100, rl-loss: 45.077312469482425
# INFO - Copied model beep parameters to target network.
# INFO - Step 207100, rl-loss: 41.637920379638674
# INFO - Copied model beep parameters to target network.
# INFO - Step 209100, rl-loss: 67.589508056640622
# INFO - Copied model beep parameters to target network.
# INFO - Step 207100, rl-loss: 24.905809402465823
# INFO - Copied model beep parameters to target network.
# INFO - Step 206100, rl-loss: 19.724386215209963
# INFO - Copied model beep parameters to target network.
# INFO - Step 208100, rl-loss: 66.385108947753962
# INFO - Copied model beep parameters to target network.
# INFO - Step 210100, rl-loss: 123.24648284912114
# INFO - Copied model beep parameters to target network.
# INFO - Step 208100, rl-loss: 50.380744934082035
# INFO - Copied model beep parameters to target network.
# INFO - Step 209100, rl-loss: 37.856346130371094
# INFO - Copied model beep parameters to target network.
# INFO - Step 207100, rl-loss: 61.035923004150394
# INFO - Copied model beep parameters to target network.
# INFO - Step 211100, rl-loss: 43.035533905029396
# INFO - Copied model beep parameters to target network.
# INFO - Step 209100, rl-loss: 87.610954284667975
# INFO - Copied model beep parameters to target network.
# INFO - Step 208100, rl-loss: 265.02224731445316
# INFO - Copied model beep parameters to target network.
# INFO - Step 210100, rl-loss: 72.790260314941422
# INFO - Copied model beep parameters to target network.
# INFO - Step 212100, rl-loss: 79.015098571777344
# INFO - Copied model beep parameters to target network.
# INFO - Step 210100, rl-loss: 41.453861236572266
# INFO - Copied model beep parameters to target network.
# INFO - Step 209100, rl-loss: 20.286800384521484
# INFO - Copied model beep parameters to target network.
# INFO - Step 211100, rl-loss: 65.372169494628955
# INFO - Copied model beep parameters to target network.
# INFO - Step 213100, rl-loss: 85.225868225097666
# INFO - Copied model beep parameters to target network.
# INFO - Step 211100, rl-loss: 262.34262084960942
# INFO - Copied model beep parameters to target network.
# INFO - Step 210067, rl-loss: 32.983295440673836
